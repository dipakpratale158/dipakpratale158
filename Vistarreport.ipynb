# %%
import pandas as pd

# Read the Excel file, specifying that the headers are in the second row (row index 1)
vistarfile = pd.read_excel(r"C:\Users\thotnr\Desktop\powerbify25\Vistar_FY24_Data.xlsx", header=1)

vistarfile[["Updated Region","Updated Hub"]]
# Out:
#      Updated Region Updated Hub
# 0        UP Central    Akbarpur
# 1        UP Central    Akbarpur
# 2        UP Central    Akbarpur
# 3        UP Central    Akbarpur
# 4        UP Central    Akbarpur
# ...             ...         ...
# 7102       Vidarbha      Nanded
# 7103       Vidarbha      Nanded
# 7104       Vidarbha      Nanded
# 7105       Vidarbha      Nanded
# 7106       Vidarbha      Nanded
#
# [7107 rows x 2 columns]

# %%
# ///////////////////////////////////dont use this code just understadind 
import shutil
import os
from tkinter import Tk
from tkinter.filedialog import askopenfilenames

# Initialize Tkinter root (not shown)
root = Tk()
root.withdraw()  # Hide the root window

# Define the Downloads folder path
downloads_folder = os.path.expanduser(r"~/Downloads")

# Open a file dialog starting in the Downloads folder and get the selected file paths
source_files = askopenfilenames(
    initialdir=downloads_folder,
    title="Select files to copy",
    filetypes=[("PDF files", "*.pdf"), ("All files", "*.*")]
)

# Define the destination folder path

#-----------------------------------------------------------------------------------------------------------------------------------------------------------
# Define the destination folder path
#EAST////////////////////////////////////////////////////T2T///////////////////////
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\T2T\Orissa"  
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\T2T\Bihar"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\T2T\Jharkhand"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\T2T\West Bangal"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\T2T\North East"

#EAST////////////////////////////////////////////////////Resional Rural Deck///////////////////////

# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Orissa"   
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Bihar"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\North East"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\West Bangal"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Jharkhand"
#-------------------------------------------------------------------------------------------------------------------------------------------------------


#NORTH////////////////////////////////////////////////////T2T///////////////////////
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\T2T\Delhi"  
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\T2T\Haryana"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\T2T\Punjab"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\T2T\Rajasthan"

#NORTH////////////////////////////////////////////////////Resional Rural Deck///////////////////////

# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Delhi"   
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Haryana"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Punjab"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Rajasthan"

#----------------------------------------------------------------------------------------------------------------------------------------------------------



#South////////////////////////////////////////////////////T2T///////////////////////
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\T2T\Andhra Pradesh"  
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\T2T\Karnataka"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\T2T\Kerala"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\T2T\Tamilnadu"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\T2T\Telangana"

#South////////////////////////////////////////////////////Resional Rural Deck///////////////////////

# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Andhra Pradesh"   
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Karnataka"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Kerala"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Tamilnadu"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Telangana"

#--------------------------------------------------------------------------------------------------------------------------------------------------------


#WEST////////////////////////////////////////////////////T2T///////////////////////
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\T2T\Chattisghar"  
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\T2T\Gujrat"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\T2T\Madhya Pradesh"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\T2T\Maharashtra"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\T2T\Vidarbha"

#WEST////////////////////////////////////////////////////Resional Rural Deck///////////////////////

# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Chattisghar"   
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Gujrat"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Madhya Pradesh"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Maharashtra"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Vidarbha"

#---------------------------------------------------------------------------------------------------------------------------------------------------------



#CENTRAL////////////////////////////////////////////////////T2T///////////////////////
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\T2T\UP Central"  
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\T2T\UP East"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\T2T\UP West"


#CENTRAL////////////////////////////////////////////////////Resional Rural Deck///////////////////////

# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP Central"   
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP East"
# destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP West"


#--------------------------------------------------------------------------------------------------------------------------------------------------------

# Function to delete all files in the destination folder
def clear_destination_folder(folder_path):
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Deleted {filename}")

# Ensure the destination folder exists, and create it if it doesn't
if not os.path.exists(destination_folder):
    os.makedirs(destination_folder)

# Clear all files in the destination folder
clear_destination_folder(destination_folder)

# Copy the selected files to the destination folder
for source_file in source_files:
    try:
        shutil.copy(source_file, destination_folder)
        print(f"Copied {os.path.basename(source_file)} to {destination_folder}")
    except FileNotFoundError:
        print(f"File not found: {source_file}")
    except PermissionError:
        print(f"Permission denied: {source_file}")
    except Exception as e:
        print(f"Error copying {source_file}: {e}")

print("All files processed.")
# Out:
# Copied UPWest(16067)-RegionalRura_PDFDocandLink_RegionalRural_PDFDocuments_1.pdf to C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP West
# All files processed.

# %%
# ////////////////////////////////////copy and past file/////////////////////////////////////////////////////////////
import os
import shutil

# Define the Downloads folder path
downloads_folder = os.path.expanduser(r"~/Downloads")

# Define the mapping of regions to destination folders
region_destination_map = {
    "UPCentral": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP Central",
    "UPWest": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP West",
    "UPEast": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP East",
    "Delhi": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Delhi",
    "Punjab": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Punjab",
    "Rajasthan": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Rajasthan",
    "Haryana": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Haryana",
    "Karnataka": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Karnataka",
    "Telangana": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Telangana",
    "AndhraPradesh": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Andhra Pradesh",
    "Tamilnadu": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Tamilnadu",
    "Maharashtra": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Maharashtra",
    "Vidarbha": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Vidarbha",
    "MadhyaPradesh": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Madhya Pradesh",
    "Jharkhand": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Jharkhand",
    "WestBengal": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\West Bangal",
    "Orissa": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Orissa",
    "Bihar": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Bihar",
        "NorthEast": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\North East",
            "Gujarat": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Gujrat",
      "Chattisgarh" : r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Chattisghar",
"Kerala" : r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Kerala"


}

# Get all files from the Downloads folder
files_in_downloads = os.listdir(downloads_folder)

# Filter PDF files
pdf_files = [f for f in files_in_downloads if f.endswith('.pdf')]

# Function to delete all files in a folder
def clear_folder(folder_path):
    if os.path.exists(folder_path):
        for filename in os.listdir(folder_path):
            file_path = os.path.join(folder_path, filename)
            if os.path.isfile(file_path):
                os.remove(file_path)
                print(f"Deleted {filename} from {folder_path}")

# Step 1: Clear all destination folders before processing
for destination_folder in region_destination_map.values():
    clear_folder(destination_folder)

# Step 2: Process each PDF file
for pdf_file in pdf_files:
    file_path = os.path.join(downloads_folder, pdf_file)
    
    # Check which region is in the file name
    for region, destination_folder in region_destination_map.items():
        if region in pdf_file:
            # Ensure the destination folder exists
            if not os.path.exists(destination_folder):
                os.makedirs(destination_folder)
            
            # Copy the file to the destination folder
            shutil.copy(file_path, destination_folder)
            print(f"Copied {pdf_file} to {destination_folder}")
            break  # Stop checking once the file is copied

print("All files processed.")
# Out:
# Copied AndhraPradesh(16059)-RegionalRura_PDFDocandLink_RegionalRural_PDFDocuments_1.pdf to C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Andhra Pradesh
# Copied BLANK,Bihar(16056)-RegionalRura_PDFDocandLink_RegionalRural_PDFDocuments_1.pdf to C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Bihar
# Copied BLANK,Chattisgarh(16054)-RegionalRura_PDFDocandLink_RegionalRural_PDFDocuments_1.pdf to C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Chattisghar
# Copied BLANK,Gujarat(16058)-RegionalRura_PDFDocandLink_RegionalRural_PDFDocuments_1.pdf to C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Gujrat
# ...

# %%
# ///////////////////////////////date format stucture file/////////////////
import os
import shutil
from datetime import datetime

# Define the base folders for different regions
regions = {
    "UPCentral": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP Central",
    "UPEast": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP East",
    "UPWest": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\Central\Resional Rural Deck\UP West",
    "Orissa": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Orissa",
    "Bihar": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Bihar",
    "Jharkhand": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\Jharkhand",
    "WestBengal": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\West Bangal",
    "NorthEast": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\East\Resional Rural Deck\North East",
    "Delhi": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Delhi",
    "Haryana": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Haryana",
    "Punjab": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Punjab",
    "Rajasthan": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\North\Resional Rural Deck\Rajasthan",
    "Karnataka": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Karnataka",
    "Telangana": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Telangana",
    "AndhraPradesh": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Andhra Pradesh",
    "Tamilnadu": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Tamilnadu",
    "Maharashtra": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Maharashtra",
    "Vidarbha": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Vidarbha",
    "MadhyaPradesh": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Madhya Pradesh",
        "Gujarat": r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Gujrat",
   "Chattisgarh" : r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\West\Resional Rural Deck\Chattisghar",
"Kerala" : r"C:\Users\thotnr\Desktop\Locationallregiondata\Download leadsquared circlewise Data\South\Resional Rural Deck\Kerala"

}

# Define the destination folder
destination_folder = r"C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA"

# Get the current month name (e.g., "Sep" for September)
current_month = datetime.now().strftime("%b").lower()

# Step 1: Delete all existing files in the destination folder
for file_name in os.listdir(destination_folder):
    file_path = os.path.join(destination_folder, file_name)
    try:
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
    except Exception as e:
        print(f"Error deleting file {file_path}: {e}")

# Step 2: Search for matching files, rename, and move them to the destination folder
for region, source_folder in regions.items():
    # Search for any PDF files that match the pattern in the source folder
    try:
        files_in_folder = os.listdir(source_folder)
    except FileNotFoundError:
        print(f"Source folder not found: {source_folder}")
        continue
    
    # Iterate over the files in the folder
    for file_name in files_in_folder:
        # Check if the file contains "RegionalRura_PDFDocandLink" and ends with .pdf
        if "RegionalRura_PDFDocandLink" in file_name and file_name.endswith(".pdf"):
            # Construct the source file path
            source_file_path = os.path.join(source_folder, file_name)
            
            # Construct the new file name based on the region and current month
            new_file_name = f"{region.replace(' ', '')}__{current_month}.pdf"
            destination_file_path = os.path.join(destination_folder, new_file_name)
            
            try:
                # Move the file to the destination with the new name
                shutil.move(source_file_path, destination_file_path)
                print(f"File renamed and moved to: {destination_file_path}")
            except Exception as e:
                print(f"Error moving file {source_file_path}: {e}")
        else:
            print(f"No matching PDF found in {source_folder} for region {region}")
# Out:
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\AndhraPradesh__sep.pdf
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\Bihar__sep.pdf
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\Delhi__sep.pdf
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\Haryana__sep.pdf
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\Jharkhand__sep.pdf
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\Karnataka__sep.pdf
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\MadhyaPradesh__sep.pdf
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\Maharashtra__sep.pdf
# Deleted file: C:\Users\thotnr\Desktop\Locationallregiondata\ALL_REGIONALRURAL_DATA\Orissa__sep.pdf
# ...

# %%
# all region file online
import webbrowser

# List of URLs you want to open
urls = [
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EchIt-bp-9hOliugt6sadPABlJIzKhfZb3W9OM8dWZzdQw?e=FxT7Oc&CID=b1df1a14-272b-e246-e7b3-c9763e025085',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/Ebj_kzwqWLRPqenoPkvzcRsBN07Iios8e7G9cLHLlbJ9mw?e=bkFEeK&CID=4a986130-1863-28f4-12b3-ac78f9d54864',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/dbhattacharya_bajajauto_co_in/EVKj6c8pvqZGqJKmggH1teoBliCmHOXLuxhDWll-V1R2ww?e=8qcNwe&CID=03c3b07d-dd02-5985-d0d4-648c2377771e',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/dbhattacharya_bajajauto_co_in/EfnnrsOpLl5BiKi0dbbAgBcBGX0pb8LcQAjmTRqjNAasUg?e=lysDsB&CID=cd28edb4-ad5b-5c47-5ded-3b813fdb91ad',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/dbhattacharya_bajajauto_co_in/EUPmfvtYozpEjUFvhl9C1j4BbVl0S8fuS-N5k1rC30Og_w?e=PPTbwU&CID=3990a2fb-f07f-4afc-59af-749d4718ae8b',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EX-cuLMSu41HphAcs76CQukBdDRqKd1yEUdZYuIdZM66Zg?e=N0xw4n&CID=dace0eef-a3c6-1768-3547-3ca5741c3519',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EdRP9dxW9wdEoi9jsnwbCewBSaKNQeXqRB8n28m4Xfd3yQ?e=ft9tB5&CID=6d967e67-aa49-2dcc-1e33-69742bc10c6c',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EbbjCEO7r3RNt5DtKgx8ujMBeq3fHLPrPvL782L95CZMYg?e=gV8dTy&CID=0fa49744-100b-e31c-44c4-d1a6228f4fe2',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EWKFF_X_WVtNtCJZ165tBk4BY2r3jhRfOfxC7LmJjDdbBQ?e=38NcIW&CID=1c29760d-f3c5-0a9a-a88b-864246f7a4ba',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EaNTe0Gk3fZApOxn8jZsDbYBztiJ9sLnTAIxE3l-BoG5uQ?e=e8yMSz&CID=19efbd19-6e50-ca46-3f47-947ac62c5ebc',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EaFVpso6b6BMkwLrCfCmfCMBX_yz5uDpUelSwv_iqX4uuA?e=JWk1hw&CID=977de7ae-a362-d188-fa08-75d1a7f47457',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EVbqtN0-o7dOufYYb6BtTNIB7BXi5DkE-osA3pp4Yb_lKw?CID=f8d2999e-a5e0-660a-28d7-6f3534b163ea',
    'https://bajajauto-my.sharepoint.com/:x:/g/personal/mafzal_bajajauto_co_in/EYYXApaIuVVJlJqUlPBZjVMBb1mO3qd3ABoZeqOTbpha2Q?e=tqKj2B&CID=b4777016-5985-9c46-f185-084112f0e243'
]

# Open each URL in the default web browser
for url in urls:
    webbrowser.open(url)

# %%
# resional rural deck open

import webbrowser

# List of URLs you want to open
urls = ['https://in21.leadsquared.com/ActivityManagement?ec=242'
   
]

# Open each URL in the default web browser
for url in urls:
    webbrowser.open(url)

# %%
# t2t open
import webbrowser

# List of URLs you want to open
urls = [
  'https://in21.leadsquared.com/ActivityManagement?ec=247'
]

# Open each URL in the default web browser
for url in urls:
    webbrowser.open(url)

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page to scrape
url = 'https://in21.leadsquared.com/ActivityManagement?ec=247'

# Make a GET request to fetch the page content
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all anchor tags (<a>)
    links = soup.find_all('a')

    # Filter and print links that start with the desired URL
    for link in links:
        href = link.get('href')
        if href and href.startswith('https://developerapp-pdf.leadsquared.com'):
            print(href)
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

# %%
import pandas as pd

# Read the Excel file, specifying that the headers are in the second row (row index 1)
vistarfile = pd.read_excel(r"C:\Users\thotnr\Desktop\Data Analysys\Vistar_Enabler_Target (2).xlsx", header=1)
