# %%
# import xlwings as xw

# def copy_jharkhand_data():
#     # Open the source workbook
#     source_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Region Deck All Regionn updated.xlsx")
#     source_ws = source_wb.sheets['Format']  # Change to your actual sheet name

#     # Get the range starting from C3 to the last used cell in that row and column
#     last_row = source_ws.range('C3').end('down').row  # Find the last row in column C
#     last_col = source_ws.range('C3').end('right').column  # Find the last column in row 3

#     # Define the data range to copy
#     data_range = source_ws.range((3, 3), (last_row, last_col))  # From C3 to the last used cell
#     data_to_copy = data_range.value  # Get the values from the specified range

#     # Open the destination workbook
#     dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _JH.xlsx")
#     dest_ws = dest_wb.sheets['Region']  # Change to your actual sheet name

#     # Clear previous data in the destination range
#     dest_ws.range('C3').expand().clear_contents()  # Clear from C3 down and right

#     # Paste the copied data into the destination
#     dest_ws.range('C3').value = data_to_copy

#     # Save and close the destination workbook
#     dest_wb.save()
#     dest_wb.close()
#     source_wb.close()

#     print("Data copied successfully from Jharkhand to the destination workbook.")

# # Run the function
# copy_jharkhand_data()

# %%
# import xlwings as xw

# def copy_jharkhand_data():
#     # Open the source workbook
#     source_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Region Deck All Regionn updated.xlsx")
#     source_ws = source_wb.sheets['Format']  # Source sheet name

#     # --- Copy data from C3 and paste into 'Region' sheet ---
#     last_row_format = source_ws.range('a3').end('down').row  # Last row in column C
#     last_col_format = source_ws.range('a3').end('right').column  # Last column in row 3
#     data_range_format = source_ws.range((3, 1), (last_row_format, last_col_format))  # From C3 to the last used cell

#     # Open the destination workbook
#     # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _JH.xlsx")
#     # ////////////////////                   Andhra pradesh
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _AP.xlsx")
#     # ////////////////////                   bhihar
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _BH.xlsx")
#     # ////////////////////                   chatticghar
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _CG.xlsx")
#      # ////////////////////                   delhi
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _DEL.xlsx")
#      # ////////////////////                   gujrat
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _GJ.xlsx")
#      # ////////////////////                   hariyana
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _HAR.xlsx")
#      # ////////////////////                   west bangal
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _WB.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _KAR.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _KER.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _MAH.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _MP.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _NE.xlsx")
#      # ////////////////////                   JHARKHAND
#     dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _ORI.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _PB.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _RAJ.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TG.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _UP C.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _UP E.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _UPW.xlsx")
#      # ////////////////////                   JHARKHAND
#     # dest_wb = xw.Book(r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _VID.xlsx")

#     # Copy data to the 'Region' sheet
#     dest_ws_region = dest_wb.sheets['Region']
#     dest_ws_region.range('a3').unmerge()  # Unmerge any merged cells before clearing
#     dest_ws_region.range('a3').expand().clear_contents()  # Clear from C3
#     dest_ws_region.range('a3').value = data_range_format.value  # Paste the data
#     dest_ws_region.range('A3:A4').merge()  # Merging A3:A4
#     dest_ws_region.range('A5:A6').merge()  # Merging A5:A6
#     dest_ws_region.range('A7:A8').merge()  # Merging A7:A8

#     # --- Copy data from C36 and paste into 'Hub - Urban' sheet ---
#     last_row_urban = source_ws.range('C36').end('down').row
#     last_col_urban = source_ws.range('C36').end('right').column
#     data_range_urban = source_ws.range((36, 3), (last_row_urban, last_col_urban))

#     dest_ws_urban = dest_wb.sheets['Hub - Urban']
#     dest_ws_urban.range('C3').unmerge()  # Unmerge any merged cells before clearing
#     dest_ws_urban.range('C3').expand().clear_contents()  # Clear existing data
#     dest_ws_urban.range('C3').value = data_range_urban.value  # Paste the copied data
#     dest_ws_region.range('A3:A4').merge()  # Merging A3:A4
#     dest_ws_region.range('A5:A6').merge()  # Merging A5:A6
#     dest_ws_region.range('A7:A8').merge()  # Merging A7:A8
#     dest_ws_region.range('A9:A10').merge()  # Merging A3:A4
#     dest_ws_region.range('A11:A12').merge()  # Merging A5:A6
#     dest_ws_region.range('A13:A14').merge()  # Merging A7:A8
#     dest_ws_region.range('A15:A16').merge()  # Merging A5:A6
#     dest_ws_region.range('A17:A18').merge()  # Merging A7:A8
#     # --- Copy data from C151 and paste into 'Hub - Rural' sheet ---
#     last_row_rural = source_ws.range('C151').end('down').row
#     last_col_rural = source_ws.range('C151').end('right').column
#     data_range_rural = source_ws.range((151, 3), (last_row_rural, last_col_rural))

#     dest_ws_rural = dest_wb.sheets['Hub - Rural']
#     dest_ws_rural.range('C3').unmerge()  # Unmerge any merged cells before clearing
#     dest_ws_rural.range('C3').expand().clear_contents()  # Clear existing data
#     dest_ws_rural.range('C3').value = data_range_rural.value  # Paste the copied data
#     dest_ws_region.range('A3:A4').merge()  # Merging A3:A4
#     dest_ws_region.range('A5:A6').merge()  # Merging A5:A6
#     dest_ws_region.range('A7:A8').merge()  # Merging A7:A8
#     dest_ws_region.range('A9:A10').merge()  # Merging A3:A4
#     dest_ws_region.range('A11:A12').merge()  # Merging A5:A6
#     dest_ws_region.range('A13:A14').merge()  # Merging A7:A8
#     dest_ws_region.range('A15:A16').merge()  # Merging A5:A6
#     dest_ws_region.range('A17:A18').merge()  # Merging A7:A8
#     # --- Copy data from BE1 and paste into 'Top & Bottom 5 ASDs - Rural' sheet ---
#     last_row_be = source_ws.range('BF3').end('down').row  # Last row in column BE
#     last_col_be = source_ws.range('BF3').end('right').column  # Last column in row 1
#     data_range_be = source_ws.range((3, 57), (last_row_be, last_col_be))  # BE1 is column 57

#     dest_ws_asd_rural = dest_wb.sheets['Top & Bottom 5 ASDs - Rural']
#     dest_ws_asd_rural.range('A3').unmerge()  # Unmerge any merged cells before clearing
#     dest_ws_asd_rural.range('A3').expand().clear_contents()  # Clear existing data
#     dest_ws_asd_rural.range('A3').value = data_range_be.value  # Paste the copied data


#       # --- Copy data from BE1 and paste into 'Top & Bottom 5 ASDs - Rural' sheet ---
#     last_row_be = source_ws.range('BF18').end('down').row  # Last row in column BE
#     last_col_be = source_ws.range('BF18').end('right').column  # Last column in row 1
#     data_range_be = source_ws.range((18, 57), (last_row_be, last_col_be))  # BE1 is column 57

#     dest_ws_asd_rural = dest_wb.sheets['Top & Bottom 5 ASDs - Rural']
#     dest_ws_asd_rural.range('A16').unmerge()  # Unmerge any merged cells before clearing
#     dest_ws_asd_rural.range('A16').expand().clear_contents()  # Clear existing data
#     dest_ws_asd_rural.range('A16').value = data_range_be.value  # Paste the copied data


#     # --- Copy data from BE1 and paste into 'Top & Bottom 5 Dealer - Rural' sheet ---
#     last_row_be = source_ws.range('AQ3').end('down').row  # Last row in column BE
#     last_col_be = source_ws.range('AQ3').end('right').column  # Last column in row 1
#     data_range_be = source_ws.range((3, 43), (last_row_be, last_col_be))  # BE1 is column 57

#     dest_ws_asd_rural = dest_wb.sheets['Top & Bottom 5 Dealers - Rural']
#     dest_ws_asd_rural.range('A3').unmerge()  # Unmerge any merged cells before clearing
#     dest_ws_asd_rural.range('A3').expand().clear_contents()  # Clear existing data
#     dest_ws_asd_rural.range('A3').value = data_range_be.value  # Paste the copied data

#     # --- Copy data from BE1 and paste into 'Top & Bottom 5 ASDs - Rural' sheet ---
#     last_row_be = source_ws.range('AQ18').end('down').row  # Last row in column BE
#     last_col_be = source_ws.range('AQ18').end('right').column  # Last column in row 1
#     data_range_be = source_ws.range((18, 43), (last_row_be, last_col_be))  # BE1 is column 57

#     dest_ws_asd_rural = dest_wb.sheets['Top & Bottom 5 Dealers - Rural']
#     dest_ws_asd_rural.range('A12').unmerge()  # Unmerge any merged cells before clearing
#     dest_ws_asd_rural.range('A12').expand().clear_contents()  # Clear existing data
#     dest_ws_asd_rural.range('A12').value = data_range_be.value  # Paste the copied data


    
#     # Save and close both workbooks
#     dest_wb.save()
#     dest_wb.close()
#     source_wb.close()

#     print("Data copied successfully to Region, Hub - Urban, Hub - Rural, and Top & Bottom 5 ASDs - Rural sheets.")

# # Run the function
# copy_jharkhand_data()

# %%
# import xlwings as xw

# def copy_data(source_wb_path, dest_wb_path):
#     # Open the source workbook
#     source_wb = xw.Book(source_wb_path)

#     # Open the destination workbook
#     dest_wb = xw.Book(dest_wb_path)

#     # Copy-paste logic for each section with additional regions
#     # 1. Format to Region
#     copy_and_paste(source_wb.sheets['Format'], 'A3', dest_wb.sheets['Region'], 'A3', merge_ranges=[('A3:A4'), ('A5:A6'), ('A7:A8')])

#     # 2. Format to Hub - Urban
#     copy_and_paste(source_wb.sheets['Format'], 'C36', dest_wb.sheets['Hub - Urban'], 'C3')

#     # 3. Format to Hub - Rural
#     copy_and_paste(source_wb.sheets['Format'], 'C151', dest_wb.sheets['Hub - Rural'], 'C3')

#     # 4. Top & Bottom 5 ASDs - Rural
#     copy_and_paste(source_wb.sheets['Format'], 'BF3', dest_wb.sheets['Top & Bottom 5 ASDs - Rural'], 'A3')
#     copy_and_paste(source_wb.sheets['Format'], 'BF18', dest_wb.sheets['Top & Bottom 5 ASDs - Rural'], 'A16')

#     # 5. Top & Bottom 5 Dealers - Rural
#     copy_and_paste(source_wb.sheets['Format'], 'AQ3', dest_wb.sheets['Top & Bottom 5 Dealers - Rural'], 'A3')
#     copy_and_paste(source_wb.sheets['Format'], 'AQ18', dest_wb.sheets['Top & Bottom 5 Dealers - Rural'], 'A12')

#     # Additional logic for the new sheets:
#     # P125 sheet logic
#     copy_and_paste(source_wb.sheets['P125'], 'A1108', dest_wb.sheets['Nil Retail ASDs - P125'], 'A3')

#     # NS125 sheet logic
#     copy_and_paste(source_wb.sheets['NS125'], 'A3', dest_wb.sheets['Nil Retail ASDs - NS125'], 'A3')

#     # P150 sheet logic
#     copy_and_paste(source_wb.sheets['P150'], 'A3', dest_wb.sheets['Nil Retail ASDs - P150'], 'A3')

#     # N150N160 sheet logic
#     copy_and_paste(source_wb.sheets['N150N160'], 'A3', dest_wb.sheets['Nil Retail ASDs - N150N160'], 'A3')

#     # NS160NS200 sheet logic
#     copy_and_paste(source_wb.sheets['NS160NS200'], 'A3', dest_wb.sheets['Nil Retail ASDs - NS160NS200'], 'A3')

#     print("Data copied and pasted successfully!")

# def copy_and_paste(source_ws, source_start_cell, dest_ws, dest_start_cell, merge_ranges=None):
#     # Determine the range to copy based on start cell
#     last_row = source_ws.range(source_start_cell).end('down').row
#     last_col = source_ws.range(source_start_cell).end('right').column
#     data_range = source_ws.range(source_start_cell, (last_row, last_col))

#     # Unmerge destination cells and clear contents
#     dest_ws.range(dest_start_cell).unmerge()
#     dest_ws.range(dest_start_cell).expand().clear_contents()

#     # Paste the data
#     dest_ws.range(dest_start_cell).value = data_range.value

#     # Apply merging if specified
#     if merge_ranges:
#         for merge_range in merge_ranges:
#             dest_ws.range(merge_range).merge()

# # Example usage
# source_wb_path = r"C:\Users\thotnr\Desktop\powerbify25\Region Deck All Regionn updated.xlsx"
# dest_wb_path = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _JH.xlsx"  # Update for each region
# copy_data(source_wb_path, dest_wb_path)

# %%
# import xlwings as xw

# def copy_top_bottom_data(sheet_name, start_cell, sum_col_index, top_n, ascending, dest_sheet, dest_range):
#     # File path
#     file_path = r"C:\Users\thotnr\Desktop\powerbify25\Region Deck All Regionn updated.xlsx"
    
#     # Open the workbook and sheets
#     wb = xw.Book(file_path)
#     src_sheet = wb.sheets[sheet_name]
#     dest_sheet = wb.sheets[dest_sheet]
    
#     # Identify the range starting from the provided start cell and expand to the table range
#     data_range = src_sheet.range(start_cell).expand("table")
    
#     # Get all data in the range (including headers)
#     data = data_range.value
    
#     # Sort the data by "Sum of Column" (ascending or descending based on the parameter)
#     # Handle None by replacing it with a large or small number depending on sorting order
#     sorted_data = sorted(
#         data[1:], 
#         key=lambda x: (float('-inf') if x[sum_col_index] is None else x[sum_col_index]), 
#         reverse=not ascending
#     )
    
#     # Get the top N rows (excluding the header row)
#     filtered_data = [data[0]] + sorted_data[:top_n]
    
#     # Paste the filtered data into the destination sheet at the specified destination range
#     dest_sheet.range(dest_range).value = filtered_data
    
#     # Save the workbook (no need to close if you're still working with it)
#     wb.save()
    
#     print(f"Top {top_n if not ascending else 'Bottom'} {top_n} data copied from '{sheet_name}' to '{dest_sheet.name}' successfully.")

# # Functions for specific tasks

# # Top 10 ASD (copied to BW2)
# def copy_top10_asd_data():
#     copy_top_bottom_data(
#         sheet_name="Top10 ASD", 
#         start_cell="A6", 
#         sum_col_index=0, 
#         top_n=10, 
#         ascending=False,  # Sort in descending order for top 10
#         dest_sheet="Format", 
#         dest_range="BW2"
#     )

# # Bottom 10 ASD (copied to BW17)
# def copy_bottom10_asd_data():
#     copy_top_bottom_data(
#         sheet_name="Bottom10 ASD", 
#         start_cell="A18", 
#         sum_col_index=0, 
#         top_n=10, 
#         ascending=True,  # Sort in ascending order for bottom 10
#         dest_sheet="Format", 
#         dest_range="BW17"
#     )

# # Top 5 Dealer (copied to CM2)
# def copy_top5_dealer_data():
#     copy_top_bottom_data(
#         sheet_name="TOP 5 Dealer", 
#         start_cell="R721", 
#         sum_col_index=16,  # Adjust column index if necessary
#         top_n=5, 
#         ascending=False,  # Sort in descending order for top 5
#         dest_sheet="Format", 
#         dest_range="CM2"
#     )

# # Bottom 5 Dealer (copied to CM17)
# def copy_bottom5_dealer_data():
#     copy_top_bottom_data(
#         sheet_name="Bottom 5 Dealer", 
#         start_cell="A4", 
#         sum_col_index=0,  # Adjust column index if necessary
#         top_n=5, 
#         ascending=True,  # Sort in ascending order for bottom 5
#         dest_sheet="Format", 
#         dest_range="CM17"
#     )

# # Running the functions
# copy_top10_asd_data()
# copy_bottom10_asd_data()
# copy_top5_dealer_data()
# copy_bottom5_dealer_data()

# %%
import pandas as pd
from pptx import Presentation
from pptx.dml.color import RGBColor
from pptx.util import Inches
from pptx.enum.text import PP_ALIGN
from pptx.enum.text import MSO_ANCHOR

# Load the Excel file
excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx"
sheet_name = 'Region'

# Read the specified range from Excel
df = pd.read_excel(excel_file, sheet_name=sheet_name, usecols='C:L', skiprows=1, nrows=6)

# Specify which columns are percentages (0-based index)
percentage_columns = [2, 5, 6, 7, 8, 9]  # E, H, I, J, K, L (C=0, D=1, E=2, F=3, G=4...)

# Convert columns to the appropriate formats
for col in df.columns:
    if df.columns.get_loc(col) in percentage_columns:
        df[col] = (df[col] * 100).map('{:.1f}%'.format)
    else:
        df[col] = df[col].astype(int).astype(str)

# Load the PowerPoint presentation
ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report tamilnadu.pptx"
presentation = Presentation(ppt_file)

# Select slide 4 (index 3 since it's zero-based)
slide = presentation.slides[3]

# Find the first table shape on slide 4
table = None
for shape in slide.shapes:
    if shape.has_table:
        table = shape.table
        break

# Check if a table was found
if table is not None:
    # Fill the table with data from the DataFrame starting from row 3, column 3 (C3)
    start_row = 2  # Row index for C3 (0-based)
    start_col = 2  # Column index for C3 (0-based)

    for i in range(len(df)):
        for j in range(len(df.columns)):
            cell = table.cell(start_row + i, start_col + j)
            cell.text = str(df.iloc[i, j])

            # Center align the cell text horizontally
            for paragraph in cell.text_frame.paragraphs:
                paragraph.alignment = PP_ALIGN.CENTER  # Center alignment for text

            # Set vertical alignment to middle
            cell.text_frame.vertical_anchor = MSO_ANCHOR.MIDDLE  # Center vertical alignment

            # Check for negative value in column G (index 6)
            if j == 6:  # G column corresponds to index 6
                value = df.iloc[i, j]
                try:
                    numeric_value = float(value.replace('%', '').strip())
                except ValueError:
                    numeric_value = None

                if numeric_value is not None and numeric_value < 0:
                    fill = cell.fill
                    fill.solid()
                    fill.fore_color.rgb = RGBColor(255, 204, 204)
else:
    print("No table found on slide 4.")

# Save the PowerPoint presentation
presentation.save(ppt_file)
print("Data copied to PowerPoint table successfully.")

# %%
# Load the Excel file
# excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx"
   excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _AP.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _JH.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _BH.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _CG.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _DEL.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _GJ.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _HAR.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _KAR.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _KER.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _MAH.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _MP.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _NE.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _ORI.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _PB.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _RAJ.xlsx"
    # excel_file =  r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TG.xlsx"
    #  excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _UPC.xlsx"
    #  excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _UPE.xlsx"
    #  excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _UPW.xlsx"
    #  excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _VID.xlsx"
    #  excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _WB.xlsx"









# Load the PowerPoint presentation
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report tamilnadu.pptx"
ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report AP.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report BH.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report CG.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report DEL.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report GJ.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report Har.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report Jharkhand.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report KAR.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report KER.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report MAH.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report MP.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report NE.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report ORI.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report PB.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report RAJ.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report TG.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report UPC.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report UPE.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report UPW.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report VID.pptx"
# ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report WB.pptx"

# %%
import openpyxl
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.text import PP_ALIGN

# List of configurations for each task
tasks = [
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx",
     "sheet_name": "Nil Retail ASDs - P125",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report TN.pptx",
     "slide_number": 11},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx",
     "sheet_name": "Nil Retail ASDs - NS125",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report TN.pptx",
     "slide_number": 12},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx",
     "sheet_name": "Nil Retail ASDs - P150",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report TN.pptx",
     "slide_number": 13},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx",
     "sheet_name": "Nil Retail ASDs - N150N160",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report TN.pptx",
     "slide_number": 14},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx",
     "sheet_name": "Nil Retail ASDs - NS160NS200",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report TN.pptx",
     "slide_number": 15},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _AP.xlsx",
     "sheet_name": "Nil Retail ASDs - P125",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report AP.pptx",
     "slide_number": 11},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _AP.xlsx",
     "sheet_name": "Nil Retail ASDs - NS125",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report AP.pptx",
     "slide_number": 12},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _AP.xlsx",
     "sheet_name": "Nil Retail ASDs - P150",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report AP.pptx",
     "slide_number": 13},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _AP.xlsx",
     "sheet_name": "Nil Retail ASDs - N150N160",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report AP.pptx",
     "slide_number": 14},
    {"excel_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _AP.xlsx",
     "sheet_name": "Nil Retail ASDs - NS160NS200",
     "pptx_path": r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report AP.pptx",
     "slide_number": 15},
    # Add other configurations here
]

# Function to format cells with two decimal places if numeric
def format_cell(cell_value):
    if isinstance(cell_value, (int, float)):
        return f"{cell_value:.0f}"  # Format without decimal points
    return str(cell_value)

# Function to adjust table columns based on content width
def autofit_columns(table, data):
    for j in range(len(data[0])):  # Loop through columns
        max_width = 0
        for i in range(len(data)):  # Loop through rows
            text_length = len(format_cell(data[i][j]))
            max_width = max(max_width, text_length * 6)  # Adjust multiplier as needed for font size
        table.columns[j].width = Inches(min(max_width / 72, 2))  # Cap width to prevent excessive stretching

# Process each task in the list
for task in tasks:
    # Load Excel workbook and extract data from the specified sheet
    wb = openpyxl.load_workbook(task["excel_path"], data_only=True)
    sheet = wb[task["sheet_name"]]
    data_rows = [[cell if cell is not None else "" for cell in row] for row in sheet.iter_rows(min_row=2, values_only=True)]

    # Determine split index for two tables
    total_rows = len(data_rows)
    if total_rows % 2 == 0:
        half_index = total_rows // 2
    else:
        half_index = total_rows // 2 + 1  # If odd, first table gets one extra row

    data_part_1 = data_rows[:half_index]
    data_part_2 = data_rows[half_index:]

    # Load PowerPoint presentation and access the specified slide
    prs = Presentation(task["pptx_path"])
    try:
        slide = prs.slides[task["slide_number"] - 1]
    except IndexError:
        print(f"Slide number {task['slide_number']} out of range. Check slide number.")
        continue

    # Remove all existing tables from the slide
    for shape in slide.shapes:
        if shape.has_table:
            sp = shape
            slide.shapes._spTree.remove(sp._element)

    # Define table dimensions and positions for the two tables
    left_1, top_1, width_1, height_1 = Inches(0.5), Inches(1), Inches(4), Inches(2)
    left_2, top_2, width_2, height_2 = Inches(5), Inches(1), Inches(4), Inches(2)

    # Create the first table and add data_part_1
    rows_1, cols_1 = len(data_part_1), len(data_part_1[0]) if data_part_1 else 0
    table_1 = slide.shapes.add_table(rows_1, cols_1, left_1, top_1, width_1, height_1).table

    for i, row in enumerate(data_part_1):
        for j, cell in enumerate(row):
            table_1.cell(i, j).text = format_cell(cell)
            table_1.cell(i, j).text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
            table_1.cell(i, j).text_frame.paragraphs[0].font.size = Pt(10)

    # Autofit column widths for the first table
    autofit_columns(table_1, data_part_1)

    # Create the second table and add data_part_2
    rows_2, cols_2 = len(data_part_2), len(data_part_2[0]) if data_part_2 else 0
    table_2 = slide.shapes.add_table(rows_2, cols_2, left_2, top_2, width_2, height_2).table

    for i, row in enumerate(data_part_2):
        for j, cell in enumerate(row):
            table_2.cell(i, j).text = format_cell(cell)
            table_2.cell(i, j).text_frame.paragraphs[0].alignment = PP_ALIGN.CENTER
            table_2.cell(i, j).text_frame.paragraphs[0].font.size = Pt(10)

    # Autofit column widths for the second table
    autofit_columns(table_2, data_part_2)

    # Save the presentation after processing each slide
    prs.save(task["pptx_path"])
    print(f"Slide {task['slide_number']} processed successfully for file {task['pptx_path']}.")

# %%
import os
import xlwings as xw
from pptx import Presentation
from pptx.util import Pt
from pptx.enum.text import PP_ALIGN

# Define folder paths
excel_folder_path = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region"
powerpoint_folder_path = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point"

# Define the ranges for data extraction
ranges = {
    "Top & Bottom 5 Dealers - Rural": ("A3:M7", "A12:M16"),
}

# Define the columns that should be formatted as percentages and whole numbers
percentage_columns = [4, 7, 8, 9, 10, 11, 12]  # Indices for percentage columns
whole_number_columns = [2, 3, 5, 6]  # Indices for whole number columns

# Function to update table cells in PowerPoint
def update_table(table, data, start_row=2):
    """Insert data starting from the specified row in the PowerPoint table."""
    for i, row in enumerate(data):
        for j, cell_value in enumerate(row):
            cell = table.cell(start_row + i, j)  # Start pasting from `start_row`
            # Format as whole number if in whole_number_columns
            if j in whole_number_columns:
                cell.text = str(int(cell_value)) if isinstance(cell_value, (int, float)) else str(cell_value)
            # Format as percentage if in percentage_columns
            elif j in percentage_columns:
                cell.text = f"{cell_value:.2%}" if isinstance(cell_value, (int, float)) else str(cell_value)
            else:
                cell.text = str(cell_value)

            # Optional: Set font size and alignment
            for paragraph in cell.text_frame.paragraphs:
                paragraph.font.size = Pt(10)  # Adjust font size as needed
                paragraph.alignment = PP_ALIGN.CENTER

# Iterate over all Excel files in the specified folder
for filename in os.listdir(excel_folder_path):
    if filename.endswith(".xlsx"):  # Only process .xlsx files
        excel_path = os.path.join(excel_folder_path, filename)

        # Open Excel workbook
        wb = xw.Book(excel_path)

        # Read data from the specified ranges in the Excel sheet
        for sheet_name, (range1, range2) in ranges.items():
            sheet = wb.sheets[sheet_name]

            # Read data from ranges
            data1 = sheet.range(range1).value
            data2 = sheet.range(range2).value

            # Iterate over all PowerPoint files in the specified folder
            for ppt_filename in os.listdir(powerpoint_folder_path):
                if ppt_filename.endswith(".pptx"):  # Only process .pptx files
                    powerpoint_path = os.path.join(powerpoint_folder_path, ppt_filename)
                    
                    # Open PowerPoint presentation
                    prs = Presentation(powerpoint_path)

                    # Find and update tables on the PowerPoint slide
                    slide = prs.slides[7]  # Slide number 8 (index starts from 0)
                    table_shapes = [shape for shape in slide.shapes if shape.has_table]

                    if len(table_shapes) >= 2:
                        table1 = table_shapes[0].table  # First table
                        table2 = table_shapes[1].table  # Second table

                        # Update PowerPoint tables with data from Excel
                        update_table(table1, data1, start_row=2)
                        update_table(table2, data2, start_row=2)

                        # Save the updated PowerPoint file
                        prs.save(powerpoint_path)
                        print(f"Data copied from {excel_path} to {ppt_filename} successfully.")

                    # Close the PowerPoint presentation
                    prs.close()

        # Close the Excel workbook
        wb.close()

# %%
import pandas as pd
from pptx import Presentation
from pptx.dml.color import RGBColor
from pptx.enum.text import PP_ALIGN
from pptx.enum.text import MSO_ANCHOR
from pptx.util import Pt  # Import to set font size

def load_data_from_excel(file_path, sheet_name, usecols, skiprows, nrows):
    """Load data from an Excel file."""
    try:
        return pd.read_excel(file_path, sheet_name=sheet_name, usecols=usecols, skiprows=skiprows, nrows=nrows)
    except Exception as e:
        print(f"Error loading data from {sheet_name}: {e}")
        return pd.DataFrame()  # Return an empty DataFrame on error

def format_dataframe(df, percentage_columns):
    """Format DataFrame columns as percentages or integers."""
    for col in df.columns:
        if col in df.columns[percentage_columns]:
            df[col] = pd.to_numeric(df[col], errors='coerce')
            df[col] = df[col].apply(lambda x: f"{x * 100:.1f}%" if pd.notnull(x) else "")
        
        elif pd.api.types.is_numeric_dtype(df[col]):
            df[col] = df[col].fillna(0).astype(int).astype(str)  # Handle NaN values for numeric columns
    
    return df

def fill_table_from_df(table, df, start_row, start_col, slide_index=None):
    """Fill PowerPoint table with data from DataFrame, ensuring dimensions match."""
    max_rows, max_cols = len(table.rows), len(table.columns)
    
    for i in range(len(df)):
        for j in range(len(df.columns)):
            if start_row + i >= max_rows or start_col + j >= max_cols:
                print(f"Skipping row {start_row + i}, column {start_col + j} - out of table bounds.")
                continue
            
            cell = table.cell(start_row + i, start_col + j)
            cell.text = str(df.iloc[i, j])
            align_cell_text(cell)
            
            # Apply font size 12 for specific slides
            if slide_index in [8, 9]:  # Check for slide 8 or 9
                for paragraph in cell.text_frame.paragraphs:
                    for run in paragraph.runs:
                        run.font.size = Pt(12)  # Set font size to 12 points
            
            # Highlight negative values in the 9th column (index 8), except for slide 8
            if j == 8 and slide_index not in [8, 16, 7]:  # Check if column is the 9th column and slide is not 8
                highlight_negative_value(cell, df.iloc[i, j])

def align_cell_text(cell):
    """Center align the text in a cell."""
    for paragraph in cell.text_frame.paragraphs:
        paragraph.alignment = PP_ALIGN.CENTER
    cell.text_frame.vertical_anchor = MSO_ANCHOR.MIDDLE

def highlight_negative_value(cell, value):
    """Highlight the cell if the value is negative."""
    try:
        numeric_value = float(value.replace('%', '').strip())
        if numeric_value < 0:
            cell.fill.solid()
            cell.fill.fore_color.rgb = RGBColor(255, 204, 204)  # Light red for negative values
        else:
            cell.fill.solid()
            cell.fill.fore_color.rgb = RGBColor(255, 255, 255)  # Set to white or default color
    except ValueError:
        pass  # Ignore if the value isn't numeric


# Load the Excel file
excel_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck All Region\Region Deck _TN.xlsx"

# Load the PowerPoint presentation
ppt_file = r"C:\Users\thotnr\Desktop\powerbify25\Regional Deck Power point\Vistaar_MC Performance Report tamilnadu.pptx"


presentation = Presentation(ppt_file)

# Define sheet-to-slide mappings and data requirements
sheets_to_process = [
    {'sheet_name': 'Region', 'slide_index': 3, 'start_row': 2, 'start_col': 0, 'usecols': 'A:L', 'skiprows': 1, 'nrows': 6, 'percentage_columns': [4, 7, 8, 9, 10, 11]},
    {'sheet_name': 'Hub - Urban', 'slide_index': 4, 'start_row': 2, 'start_col': 0, 'usecols': 'A:L', 'skiprows': 1, 'nrows': 16, 'percentage_columns': [4, 7, 8, 9, 10, 11]},
    {'sheet_name': 'Hub - Rural', 'slide_index': 5, 'start_row': 2, 'start_col': 0, 'usecols': 'A:L', 'skiprows': 1, 'nrows': 16, 'percentage_columns': [4, 7, 8, 9, 10, 11]},
    {'sheet_name': 'Top & Bottom 5 Dealers - Rural', 'slide_index': 7, 'start_row': 2, 'start_col': 0, 'usecols': 'A:M', 'skiprows': 1, 'nrows': 5, 'percentage_columns': [4, 7, 8, 9, 10, 11, 12]},
    {'sheet_name': 'Bottom 5 Dealers - Rural', 'slide_index': 16, 'start_row': 2, 'start_col': 0, 'usecols': 'A:M', 'skiprows': 1, 'nrows': 5, 'percentage_columns': [4, 7, 8, 9, 10, 11, 12]},
    {'sheet_name': 'Top & Bottom 5 ASDs - Rural', 'slide_index': 8, 'start_row': 2, 'start_col': 0, 'usecols': 'A:N', 'skiprows': 1, 'nrows': 10, 'percentage_columns': [5, 8, 9, 10, 11, 12, 13]},
    {'sheet_name': 'Top & Bottom 5 ASDs - Rural', 'slide_index': 9, 'start_row': 2, 'start_col': 0, 'usecols': 'A:N', 'skiprows': 14, 'nrows': 10, 'percentage_columns': [5, 8, 9, 10, 11, 12, 13]}
]

# Process each sheet and fill corresponding slide tables
for sheet_info in sheets_to_process:
    df = load_data_from_excel(excel_file, sheet_info['sheet_name'], sheet_info['usecols'], sheet_info['skiprows'], sheet_info['nrows'])
    if df.empty:
        continue  # Skip to the next sheet if there's no data
    
    df = format_dataframe(df, sheet_info['percentage_columns'])
    
    slide = presentation.slides[sheet_info['slide_index']]
    table = next((shape.table for shape in slide.shapes if shape.has_table), None)
    
    if table is not None:
        fill_table_from_df(table, df, sheet_info['start_row'], sheet_info['start_col'], sheet_info['slide_index'])
    else:
        print(f"No table found on slide {sheet_info['slide_index'] + 1}.")

# Save the PowerPoint presentation
presentation.save(ppt_file)
print("Data copied to PowerPoint tables successfully.")
